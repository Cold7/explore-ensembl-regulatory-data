# %%
import urllib.request

fp = urllib.request.urlopen("ftp://ftp.ensembl.org/pub/release-101/regulation/mus_musculus/Peaks/")
mybytes = fp.read()

mystr = mybytes.decode("utf8")
fp.close()

data = mystr.split("\n")
cellDict = {}

# %%
for item in data:
    if item != "" and item != "\n":
        cell = item.split(" ")[-1][:-1]
        print(cell)
        cellDict[cell] = []
        fp = urllib.request.urlopen("ftp://ftp.ensembl.org/pub/release-101/regulation/mus_musculus/Peaks/"+cell+"/")
        mybytes = fp.read()
        mystr = mybytes.decode("utf8")
        fp.close()
        
        data2 = mystr.split("\n")
        for item in data2:
            item = item.split(" ")[-1][:-1]
            
            cellDict[cell].append(item)
# Out:
# CH12_LX
# ES_Bruce4_embryonic
# MEL_cell_line
# bone_marrow_adult_8_weeks
# embryonic_facial_prominence_embryonic_10_5_days
# embryonic_facial_prominence_embryonic_11_5_days
# embryonic_facial_prominence_embryonic_12_5_days
# embryonic_facial_prominence_embryonic_13_5_days
# embryonic_facial_prominence_embryonic_14_5_days
# embryonic_facial_prominence_embryonic_15_5_days
# forebrain_embryonic_10_5_days
# forebrain_embryonic_11_5_days
# forebrain_embryonic_12_5_days
# forebrain_embryonic_13_5_days
# forebrain_embryonic_14_5_days
# forebrain_embryonic_15_5_days
# forebrain_embryonic_16_5_days
# forebrain_postnatal_0_days
# heart_adult_8_weeks
# heart_embryonic_10_5_days
# heart_embryonic_11_5_days
# heart_embryonic_12_5_days
# heart_embryonic_13_5_days
# heart_embryonic_14_5_days
# heart_embryonic_15_5_days
# heart_embryonic_16_5_days
# heart_postnatal_0_days
# hindbrain_embryonic_10_5_days
# hindbrain_embryonic_11_5_days
# hindbrain_embryonic_12_5_days
# hindbrain_embryonic_13_5_days
# hindbrain_embryonic_14_5_days
# hindbrain_embryonic_15_5_days
# hindbrain_embryonic_16_5_days
# hindbrain_postnatal_0_days
# intestine_embryonic_14_5_days
# intestine_embryonic_15_5_days
# intestine_embryonic_16_5_days
# intestine_postnatal_0_days
# kidney_adult_8_weeks
# kidney_embryonic_14_5_days
# kidney_embryonic_15_5_days
# kidney_embryonic_16_5_days
# kidney_postnatal_0_days
# limb_embryonic_10_5_days
# limb_embryonic_11_5_days
# limb_embryonic_12_5_days
# limb_embryonic_13_5_days
# limb_embryonic_14_5_days
# limb_embryonic_15_5_days
# liver_adult_8_weeks
# liver_embryonic_11_5_days
# liver_embryonic_12_5_days
# liver_embryonic_13_5_days
# liver_embryonic_14_5_days
# liver_embryonic_15_5_days
# liver_embryonic_16_5_days
# liver_postnatal_0_days
# lung_embryonic_14_5_days
# lung_embryonic_15_5_days
# lung_embryonic_16_5_days
# lung_postnatal_0_days
# midbrain_embryonic_10_5_days
# midbrain_embryonic_11_5_days
# midbrain_embryonic_12_5_days
# midbrain_embryonic_13_5_days
# midbrain_embryonic_14_5_days
# midbrain_embryonic_15_5_days
# midbrain_embryonic_16_5_days
# midbrain_postnatal_0_days
# neural_tube_embryonic_11_5_days
# neural_tube_embryonic_12_5_days
# neural_tube_embryonic_13_5_days
# neural_tube_embryonic_14_5_days
# neural_tube_embryonic_15_5_days
# spleen_adult_8_weeks
# stomach_embryonic_14_5_days
# stomach_embryonic_15_5_days
# stomach_embryonic_16_5_days
# stomach_postnatal_0_days
# thymus_adult_8_weeks

# %%
for item in cellDict:
    print(item, cellDict[item])
# Out:
# CH12_LX ['BHLHE40', 'CHD1', 'CHD2', 'CTCF', 'DNase1', 'E2F4', 'ELF1', 'EP300', 'ETS1', 'GABPA', 'H3K27ac', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'HCFC1', 'IRF4', 'JUN', 'JUND', 'KAT2A', 'MAFK', 'MAZ', 'MEF2A', 'MXI1', 'MYC', 'Max', 'NELFe', 'NRF1', 'PAX5', 'PolII', 'RCOR1', 'Rad21', 'SIN3A', 'SMC3', 'TBP', 'TCF12', 'UBTF', 'USF1', 'USF2', 'ZC3H11A', 'ZKSCAN1', 'ZMIZ1', 'ZNF384', '']
# ES_Bruce4_embryonic ['CTCF', 'EP300', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9ac', 'H3K9me3', 'PolII', '']
# MEL_cell_line ['BHLHE40', 'CHD1', 'CHD2', 'CTCF', 'DNase1', 'E2F4', 'ELF1', 'EP300', 'ETS1', 'GABPA', 'GATA1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9ac', 'H3K9me3', 'HCFC1', 'JUND', 'KAT2A', 'MAFK', 'MAZ', 'MEF2A', 'MXI1', 'MYB', 'MYC', 'Max', 'NELFe', 'NRF1', 'PolII', 'RCOR1', 'Rad21', 'SIN3A', 'SMC3', 'TAL1', 'TBP', 'TCF12', 'UBTF', 'USF1', 'USF2', 'ZC3H11A', 'ZKSCAN1', 'ZMIZ1', 'ZNF384', '']
# bone_marrow_adult_8_weeks ['CTCF', 'PolII', '']
# embryonic_facial_prominence_embryonic_10_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', '']
# embryonic_facial_prominence_embryonic_11_5_days ['DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# embryonic_facial_prominence_embryonic_12_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# embryonic_facial_prominence_embryonic_13_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# embryonic_facial_prominence_embryonic_14_5_days ['DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# embryonic_facial_prominence_embryonic_15_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# forebrain_embryonic_10_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', '']
# forebrain_embryonic_11_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# forebrain_embryonic_12_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# forebrain_embryonic_13_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# forebrain_embryonic_14_5_days ['DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# forebrain_embryonic_15_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# forebrain_embryonic_16_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# forebrain_postnatal_0_days ['CTCF', 'DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# heart_adult_8_weeks ['CTCF', 'DNase1', 'EP300', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9ac', 'PolII', '']
# heart_embryonic_10_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', '']
# heart_embryonic_11_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# heart_embryonic_12_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# heart_embryonic_13_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# heart_embryonic_14_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# heart_embryonic_15_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# heart_embryonic_16_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# heart_postnatal_0_days ['CTCF', 'DNase1', 'EP300', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# hindbrain_embryonic_10_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', '']
# hindbrain_embryonic_11_5_days ['DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# hindbrain_embryonic_12_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# hindbrain_embryonic_13_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# hindbrain_embryonic_14_5_days ['DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# hindbrain_embryonic_15_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# hindbrain_embryonic_16_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# hindbrain_postnatal_0_days ['CTCF', 'DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# intestine_embryonic_14_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# intestine_embryonic_15_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# intestine_embryonic_16_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# intestine_postnatal_0_days ['CTCF', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# kidney_adult_8_weeks ['CTCF', 'DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'PolII', '']
# kidney_embryonic_14_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# kidney_embryonic_15_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# kidney_embryonic_16_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# kidney_postnatal_0_days ['CTCF', 'DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# limb_embryonic_10_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', '']
# limb_embryonic_11_5_days ['DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# limb_embryonic_12_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# limb_embryonic_13_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# limb_embryonic_14_5_days ['DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# limb_embryonic_15_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# liver_adult_8_weeks ['CTCF', 'DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9ac', 'PolII', '']
# liver_embryonic_11_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# liver_embryonic_12_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# liver_embryonic_13_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# liver_embryonic_14_5_days ['CTCF', 'DNase1', 'EP300', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# liver_embryonic_15_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# liver_embryonic_16_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# liver_postnatal_0_days ['CTCF', 'DNase1', 'EP300', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# lung_embryonic_14_5_days ['CTCF', 'DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# lung_embryonic_15_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# lung_embryonic_16_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# lung_postnatal_0_days ['CTCF', 'DNase1', 'EP300', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# midbrain_embryonic_10_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', '']
# midbrain_embryonic_11_5_days ['DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# midbrain_embryonic_12_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# midbrain_embryonic_13_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# midbrain_embryonic_14_5_days ['DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# midbrain_embryonic_15_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# midbrain_embryonic_16_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# midbrain_postnatal_0_days ['CTCF', 'DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# neural_tube_embryonic_11_5_days ['DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# neural_tube_embryonic_12_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# neural_tube_embryonic_13_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# neural_tube_embryonic_14_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# neural_tube_embryonic_15_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# spleen_adult_8_weeks ['CTCF', 'DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'PolII', '']
# stomach_embryonic_14_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# stomach_embryonic_15_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# stomach_embryonic_16_5_days ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# stomach_postnatal_0_days ['CTCF', 'DNase1', 'EP300', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K9ac', 'H3K9me3', '']
# thymus_adult_8_weeks ['CTCF', 'DNase1', 'H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'PolII', '']

# %%
#to know the full HM to create dictionaries
hmList = []
for cell in cellDict:
    for item in cellDict[cell]:
        if item != "":
            if "H1" == item[:2] or "H2" == item[:2] or "H3" == item[:2] or "H4" == item[:2]:
                if item not in hmList:
                    hmList.append(item)
                    
for hm in hmList:
    print("\t\""+hm.lower()+"\":False")
# Out:
# 	"h3k27ac":False
# 	"h3k36me3":False
# 	"h3k4me1":False
# 	"h3k4me2":False
# 	"h3k4me3":False
# 	"h3k9ac":False
# 	"h3k27me3":False
# 	"h3k9me3":False

# %%
finalDict = {}
for cell in cellDict:
    finalDict[cell] = {
        "dnase1": 0, 
        "h3k27ac":0,
        "h3k27me3":0,
        "h3k36me3":0,
        "h3k4me1":0,
        "h3k4me3":0,
        "h3k9me3":0,
        "h3k4me2":0,
        "h3k9ac":0,
        "h4k20me1":0,
        "h2ak5ac":0,
        "h2bk120ac":0,
        "h2bk12ac":0,
        "h2bk15ac":0,
        "h2bk20ac":0,
        "h2bk5ac":0,
        "h3k14ac":0,
        "h3k18ac":0,
        "h3k23ac":0,
        "h3k23me2":0,
        "h3k4ac":0,
        "h3k56ac":0,
        "h3k79me1":0,
        "h3k79me2":0,
        "h4k5ac":0,
        "h4k8ac":0,
        "h4k91ac":0,
        "h2az":0,
        "h3k9me1":0,
        "h2ak9ac":0,
        "h2a.zac":0,
        "h4k12ac":0,
        "ezh2":0,
        "yy1":0, 
        "ctcf":0}#,
#        "TFs": 0}
    for item in cellDict[cell]:
        if item != "" and "pol" not in item.lower():
                if item.lower() in finalDict[cell]:
                    finalDict[cell][item.lower()] = 1
#                else:
#                    finalDict[cell]["TFs"] += 1

# %%
import pandas as pd
df = pd.DataFrame.from_dict(finalDict)
df2 = df.transpose()
df2.to_csv("data_ensembl.tsv", sep="\t")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline



factor = 2
fig, ax = plt.subplots(1, 1, figsize = (4*3, 3*10), dpi = 100)

sns.heatmap(df2, cmap='Greens', annot=True, ax = ax)
# fig = sns_plot.get_figure()
# fig.savefig("output.svg",  format='svg', dpi=1200, bbox_to_anchor = 'tight')
plt.show()

# %%
#doing histogram of experiments

#getting freq of exp
histDict = {}
for cell in  finalDict:
    for exp_name in finalDict[cell]:
        if exp_name not in histDict:
            histDict[exp_name] = finalDict[cell][exp_name]
        else:
            histDict[exp_name] += finalDict[cell][exp_name]

            
#getting names
names = list(histDict)
plt.bar(range(len(histDict)), list(histDict.values()), align='center')
plt.xticks(range(len(histDict)), list(histDict.keys()))
# Out:
# ([<matplotlib.axis.XTick at 0x7f658d92df28>,
#   <matplotlib.axis.XTick at 0x7f658d92db00>,
#   <matplotlib.axis.XTick at 0x7f658d92d748>,
#   <matplotlib.axis.XTick at 0x7f658d7099b0>,
#   <matplotlib.axis.XTick at 0x7f658d709e48>,
#   <matplotlib.axis.XTick at 0x7f658d717320>,
#   <matplotlib.axis.XTick at 0x7f658d7177b8>,
#   <matplotlib.axis.XTick at 0x7f658d717748>,
#   <matplotlib.axis.XTick at 0x7f658d717ba8>,
#   <matplotlib.axis.XTick at 0x7f658d725080>,
#   <matplotlib.axis.XTick at 0x7f658d725518>,
#   <matplotlib.axis.XTick at 0x7f658d7259b0>,
#   <matplotlib.axis.XTick at 0x7f658d725e48>,
#   <matplotlib.axis.XTick at 0x7f658d72d320>,
#   <matplotlib.axis.XTick at 0x7f658d72d7b8>,
#   <matplotlib.axis.XTick at 0x7f658d72dc50>,
#   <matplotlib.axis.XTick at 0x7f658d725128>,
#   <matplotlib.axis.XTick at 0x7f658d72d978>,
#   <matplotlib.axis.XTick at 0x7f658d72df98>,
#   <matplotlib.axis.XTick at 0x7f658d731470>,
#   <matplotlib.axis.XTick at 0x7f658d731908>,
#   <matplotlib.axis.XTick at 0x7f658d731da0>,
#   <matplotlib.axis.XTick at 0x7f658d739278>,
#   <matplotlib.axis.XTick at 0x7f658d739710>,
#   <matplotlib.axis.XTick at 0x7f658d739ba8>,
#   <matplotlib.axis.XTick at 0x7f658d731588>,
#   <matplotlib.axis.XTick at 0x7f658d725ef0>,
#   <matplotlib.axis.XTick at 0x7f658d739e10>,
#   <matplotlib.axis.XTick at 0x7f658d7442e8>,
#   <matplotlib.axis.XTick at 0x7f658d744780>,
#   <matplotlib.axis.XTick at 0x7f658d744c18>,
#   <matplotlib.axis.XTick at 0x7f658d74c0f0>,
#   <matplotlib.axis.XTick at 0x7f658d74c588>,
#   <matplotlib.axis.XTick at 0x7f658d74ca20>,
#   <matplotlib.axis.XTick at 0x7f658d744518>],
#  [Text(0, 0, 'dnase1'),
#   Text(1, 0, 'h3k27ac'),
#   Text(2, 0, 'h3k27me3'),
#   Text(3, 0, 'h3k36me3'),
#   Text(4, 0, 'h3k4me1'),
#   Text(5, 0, 'h3k4me3'),
#   Text(6, 0, 'h3k9me3'),
#   Text(7, 0, 'h3k4me2'),
#   Text(8, 0, 'h3k9ac'),
#   Text(9, 0, 'h4k20me1'),
#   Text(10, 0, 'h2ak5ac'),
#   Text(11, 0, 'h2bk120ac'),
#   Text(12, 0, 'h2bk12ac'),
#   Text(13, 0, 'h2bk15ac'),
#   Text(14, 0, 'h2bk20ac'),
#   Text(15, 0, 'h2bk5ac'),
#   Text(16, 0, 'h3k14ac'),
#   Text(17, 0, 'h3k18ac'),
#   Text(18, 0, 'h3k23ac'),
#   Text(19, 0, 'h3k23me2'),
#   Text(20, 0, 'h3k4ac'),
#   Text(21, 0, 'h3k56ac'),
#   Text(22, 0, 'h3k79me1'),
#   Text(23, 0, 'h3k79me2'),
#   Text(24, 0, 'h4k5ac'),
#   Text(25, 0, 'h4k8ac'),
#   Text(26, 0, 'h4k91ac'),
#   Text(27, 0, 'h2az'),
#   Text(28, 0, 'h3k9me1'),
#   Text(29, 0, 'h2ak9ac'),
#   Text(30, 0, 'h2a.zac'),
#   Text(31, 0, 'h4k12ac'),
#   Text(32, 0, 'ezh2'),
#   Text(33, 0, 'yy1'),
#   Text(34, 0, 'ctcf')])

# %%
#based on the plot, we select subsets of data to know wich cell/tissues I can use with the regulatory features of ensembl
first_data = ['dnase1','h3k27ac','h3k27me3','h3k36me3','h3k4me1','h3k4me3','h3k9me3','ctcf']
second_data = ['dnase1','h3k27ac','h3k27me3','h3k36me3','h3k4me1','h3k4me3','h3k9me3','h3k4me2','h3k9ac','ctcf']
third_data = ['dnase1','h3k27ac','h3k27me3','h3k36me3','h3k4me1','h3k4me3','h3k9me3']
fourth_data = ['dnase1','h3k27ac','h3k27me3','h3k36me3','h3k4me1','h3k4me3','h3k9me3','h3k4me2','h3k9ac']

#list where cells will be append if it have all the data
first_cell = []
second_cell = []
third_cell = []
fourth_cell = []
#now im going to search for these cell lines with all the data
for cell in finalDict:
    count_first = 0
    count_second = 0
    count_third = 0
    count_fourth = 0
    for exp in finalDict[cell]:
        if exp in first_data:
            count_first += finalDict[cell][exp]
        if exp in second_data:
            count_second += finalDict[cell][exp]
        if exp in third_data:
            count_third += finalDict[cell][exp]
        if exp in fourth_data:
            count_fourth += finalDict[cell][exp]
    if count_first == len(first_data):
        first_cell.append(cell)
    if count_second == len(second_data):
        second_cell.append(cell)        
    if count_third == len(third_data):
        third_cell.append(cell)
    if count_fourth == len(fourth_data):
        fourth_cell.append(cell)

print("cells for the first dataset")
print(first_cell)
print("cells for the second dataset")
print(second_cell)
print("cells for the third dataset")
print(third_cell)
print("cells for the fourth dataset")
print(fourth_cell)
# Out:
# cells for the first dataset
# ['MEL_cell_line', 'forebrain_postnatal_0_days', 'heart_postnatal_0_days', 'hindbrain_postnatal_0_days', 'kidney_postnatal_0_days', 'liver_embryonic_14_5_days', 'liver_postnatal_0_days', 'lung_embryonic_14_5_days', 'lung_postnatal_0_days', 'midbrain_postnatal_0_days', 'stomach_postnatal_0_days']
# cells for the second dataset
# ['forebrain_postnatal_0_days', 'heart_postnatal_0_days', 'hindbrain_postnatal_0_days', 'kidney_postnatal_0_days', 'liver_embryonic_14_5_days', 'liver_postnatal_0_days', 'lung_embryonic_14_5_days', 'lung_postnatal_0_days', 'midbrain_postnatal_0_days', 'stomach_postnatal_0_days']
# cells for the third dataset
# ['MEL_cell_line', 'embryonic_facial_prominence_embryonic_11_5_days', 'embryonic_facial_prominence_embryonic_14_5_days', 'forebrain_embryonic_14_5_days', 'forebrain_postnatal_0_days', 'heart_postnatal_0_days', 'hindbrain_embryonic_11_5_days', 'hindbrain_embryonic_14_5_days', 'hindbrain_postnatal_0_days', 'kidney_postnatal_0_days', 'limb_embryonic_11_5_days', 'limb_embryonic_14_5_days', 'liver_embryonic_14_5_days', 'liver_postnatal_0_days', 'lung_embryonic_14_5_days', 'lung_postnatal_0_days', 'midbrain_embryonic_11_5_days', 'midbrain_embryonic_14_5_days', 'midbrain_postnatal_0_days', 'neural_tube_embryonic_11_5_days', 'stomach_postnatal_0_days']
# cells for the fourth dataset
# ['embryonic_facial_prominence_embryonic_11_5_days', 'embryonic_facial_prominence_embryonic_14_5_days', 'forebrain_embryonic_14_5_days', 'forebrain_postnatal_0_days', 'heart_postnatal_0_days', 'hindbrain_embryonic_11_5_days', 'hindbrain_embryonic_14_5_days', 'hindbrain_postnatal_0_days', 'kidney_postnatal_0_days', 'limb_embryonic_11_5_days', 'limb_embryonic_14_5_days', 'liver_embryonic_14_5_days', 'liver_postnatal_0_days', 'lung_embryonic_14_5_days', 'lung_postnatal_0_days', 'midbrain_embryonic_11_5_days', 'midbrain_embryonic_14_5_days', 'midbrain_postnatal_0_days', 'neural_tube_embryonic_11_5_days', 'stomach_postnatal_0_days']

# %%
# merging all cells in just a non repeated list
all = first_cell+ second_cell+ third_cell+ fourth_cell
noRepeat = []
for item in all:
    if item not in noRepeat:
        noRepeat.append(item)
print(noRepeat)
# Out:
# ['MEL_cell_line', 'forebrain_postnatal_0_days', 'heart_postnatal_0_days', 'hindbrain_postnatal_0_days', 'kidney_postnatal_0_days', 'liver_embryonic_14_5_days', 'liver_postnatal_0_days', 'lung_embryonic_14_5_days', 'lung_postnatal_0_days', 'midbrain_postnatal_0_days', 'stomach_postnatal_0_days', 'embryonic_facial_prominence_embryonic_11_5_days', 'embryonic_facial_prominence_embryonic_14_5_days', 'forebrain_embryonic_14_5_days', 'hindbrain_embryonic_11_5_days', 'hindbrain_embryonic_14_5_days', 'limb_embryonic_11_5_days', 'limb_embryonic_14_5_days', 'midbrain_embryonic_11_5_days', 'midbrain_embryonic_14_5_days', 'neural_tube_embryonic_11_5_days']

# %%
#looking for those cell lines with methylation data available
methWeb = "ftp://ftp.ensembl.org/pub/data_files/mus_musculus/GRCm38/dna_methylation_feature/"
fp = urllib.request.urlopen(methWeb)
mybytes = fp.read()

mystr = mybytes.decode("utf8")
fp.close()

data = mystr.split("\n")
methCell = []
print("Printing those cells in noRepeat list with meth data")
for d in data:
    cell = d.split(" ")[-1].split("_")[0]
    if cell in noRepeat:
        methCell.append(cell)
        print(cell)
# Out:
# Printing those cells in noRepeat list with meth data

# %%
#doing a image of cell/tissue and the available data
#for this we will use noRepeat list and second_data list plus meth

#creading a panda dataframe
dictSelectedCells = {}
for cell in noRepeat:
    for cell2 in finalDict:
        if cell == cell2:
            #looking if cell have meth data
            currentMeth = 0
            if cell in methCell:
                currentMeth = 1
            dictSelectedCells[cell] = {            
                'dnase1':finalDict[cell]['dnase1'],
                'h3k27ac':finalDict[cell]['h3k27ac'],
                'h3k27me3':finalDict[cell]['h3k27me3'],
                'h3k36me3':finalDict[cell]['h3k36me3'],
                'h3k4me1':finalDict[cell]['h3k4me1'],
                'h3k4me3':finalDict[cell]['h3k4me3'],
                'h3k9me3':finalDict[cell]['h3k9me3'],
                'h3k4me2':finalDict[cell]['h3k4me2'],
                'h3k9ac':finalDict[cell]['h3k9ac'],
                'ctcf':finalDict[cell]['ctcf'],
                'methylation':currentMeth
            }

df3 = pd.DataFrame.from_dict(dictSelectedCells)
df4 = df3.transpose()

factor = 2
fig, ax = plt.subplots(1, 1, figsize = (4*3, 3*10), dpi = 100)

sns.heatmap(df4, cmap='Greens', annot=True, ax = ax)
# fig = sns_plot.get_figure()
# fig.savefig("output.svg",  format='svg', dpi=1200, bbox_to_anchor = 'tight')
plt.show()

# %%
"""Date: September 11, 2020"""
# Out:
# 'Date: August 24, 2020'
